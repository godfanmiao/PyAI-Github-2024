# %%
##################################################################
#《Python机器学习及实践：从零开始通往Kaggle竞赛之路（2023年度版）》开源代码
#-----------------------------------------------------------------
#                 @章节号：7.1（PySpark环境配置）                           
#                 @作者：范淼                                      
#                 @电子邮箱：fanmiao.cslt.thu@gmail.com             
#                 @微博：https://weibo.com/fanmiaothu             
#                 @官方交流QQ群号：561500762                        
##################################################################

# %%
#在终端/命令行提示符中，依次输入如下指令，配置用于运行本章代码的编程环境。

#0）安装JRE。

#1) 创建虚拟环境python_spark，并使用Python 3.8解释器：conda create -n python_spark python=3.8

#2) 切换到虚拟环境python_spark：conda activate python_spark

#3) 在虚拟环境python_spark中安装Jupyter Notebook：conda install notebook

#4) 启动Jupyter Notebook：jupyter notebook

# %%
#查验当前虚拟环境是否已经安装了指定版本的PySpark编程库。
# !conda install pyspark==3.1.2
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
#查验当前虚拟环境是否已经安装了指定版本的Pandas编程库。
# !conda install pandas==1.3.4
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
import pyspark

pyspark.__version__
# Out:
# '3.1.2'

# %%
import pandas as pd

pd.__version__
# Out:
# '1.3.4'
